# %% [markdown]
# # Filtering and Ordering

# %%
import pandas as pd

# %%
df = pd.read_csv(r"world_population.csv")

# %%
df
# Out:
#      Rank CCA3  ... Growth Rate World Population Percentage
# 0      36  AFG  ...      1.0257                        0.52
# 1     138  ALB  ...      0.9957                        0.04
# 2      34  DZA  ...      1.0164                        0.56
# 3     213  ASM  ...      0.9831                        0.00
# 4     203  AND  ...      1.0100                        0.00
# ..    ...  ...  ...         ...                         ...
# 229   226  WLF  ...      0.9953                        0.00
# 230   172  ESH  ...      1.0184                        0.01
# 231    46  YEM  ...      1.0217                        0.42
# 232    63  ZMB  ...      1.0280                        0.25
# 233    74  ZWE  ...      1.0204                        0.20
#
# [234 rows x 17 columns]

# %%
df.head()
# Out:
#    Rank CCA3  ... Growth Rate World Population Percentage
# 0    36  AFG  ...      1.0257                        0.52
# 1   138  ALB  ...      0.9957                        0.04
# 2    34  DZA  ...      1.0164                        0.56
# 3   213  ASM  ...      0.9831                        0.00
# 4   203  AND  ...      1.0100                        0.00
#
# [5 rows x 17 columns]

# %%
df[df['Rank'] <= 10]
# Out:
#      Rank CCA3  ... Growth Rate World Population Percentage
# 16      8  BGD  ...      1.0108                        2.15
# 27      7  BRA  ...      1.0046                        2.70
# 41      1  CHN  ...      1.0000                       17.88
# 92      2  IND  ...      1.0068                       17.77
# 93      4  IDN  ...      1.0064                        3.45
# 131    10  MEX  ...      1.0063                        1.60
# 149     6  NGA  ...      1.0241                        2.74
# 156     5  PAK  ...      1.0191                        2.96
# 171     9  RUS  ...      0.9973                        1.81
# 221     3  USA  ...      1.0038                        4.24
#
# [10 rows x 17 columns]

# %%
specific_countries = ['Bangladesh','Brazil']

df[df['Country'].isin(specific_countries)]
# Out:
#     Rank CCA3  ... Growth Rate World Population Percentage
# 16     8  BGD  ...      1.0108                        2.15
# 27     7  BRA  ...      1.0046                        2.70
#
# [2 rows x 17 columns]

# %%
df[df['Country'].str.contains('United')]
# Out:
#      Rank CCA3  ... Growth Rate World Population Percentage
# 219    97  ARE  ...      1.0081                        0.12
# 220    21  GBR  ...      1.0034                        0.85
# 221     3  USA  ...      1.0038                        4.24
# 222   200  VIR  ...      0.9937                        0.00
#
# [4 rows x 17 columns]

# %%
df2 = df.set_index('Country')
df2
# Out:
#                    Rank CCA3  ... Growth Rate World Population Percentage
# Country                       ...
# Afghanistan          36  AFG  ...      1.0257                        0.52
# Albania             138  ALB  ...      0.9957                        0.04
# Algeria              34  DZA  ...      1.0164                        0.56
# American Samoa      213  ASM  ...      0.9831                        0.00
# Andorra             203  AND  ...      1.0100                        0.00
# ...                 ...  ...  ...         ...                         ...
# Wallis and Futuna   226  WLF  ...      0.9953                        0.00
# Western Sahara      172  ESH  ...      1.0184                        0.01
# Yemen                46  YEM  ...      1.0217                        0.42
# Zambia               63  ZMB  ...      1.0280                        0.25
# Zimbabwe             74  ZWE  ...      1.0204                        0.20
#
# [234 rows x 16 columns]

# %%
df2.filter(items = ['Continent','CCA3'], axis = 1)
# Out:
#                   Continent CCA3
# Country
# Afghanistan            Asia  AFG
# Albania              Europe  ALB
# Algeria              Africa  DZA
# American Samoa      Oceania  ASM
# Andorra              Europe  AND
# ...                     ...  ...
# Wallis and Futuna   Oceania  WLF
# Western Sahara       Africa  ESH
# Yemen                  Asia  YEM
# Zambia               Africa  ZMB
# Zimbabwe             Africa  ZWE
#
# [234 rows x 2 columns]

# %%
df2.filter(items = ['Zimbabwe'], axis = 0)
# Out:
#           Rank CCA3  ... Growth Rate World Population Percentage
# Country              ...
# Zimbabwe    74  ZWE  ...      1.0204                         0.2
#
# [1 rows x 16 columns]

# %%
df2.filter(like = 'United', axis = 0)
# Out:
#                               Rank  ... World Population Percentage
# Country                             ...
# United Arab Emirates            97  ...                        0.12
# United Kingdom                  21  ...                        0.85
# United States                    3  ...                        4.24
# United States Virgin Islands   200  ...                        0.00
#
# [4 rows x 16 columns]

# %%
df2.loc['United States']
# Out:
# Rank                                          3
# CCA3                                        USA
# Capital                        Washington, D.C.
# Continent                         North America
# 2022 Population                     338289857.0
# 2020 Population                     335942003.0
# 2015 Population                     324607776.0
# 2010 Population                     311182845.0
# 2000 Population                     282398554.0
# 1990 Population                     248083732.0
# 1980 Population                     223140018.0
# 1970 Population                     200328340.0
# Area (km²)                            9372610.0
# Density (per km²)                       36.0935
# Growth Rate                              1.0038
# World Population Percentage                4.24
# Name: United States, dtype: object

# %%
df2.iloc[3]
# Out:
# Rank                                 213
# CCA3                                 ASM
# Capital                        Pago Pago
# Continent                        Oceania
# 2022 Population                  44273.0
# 2020 Population                  46189.0
# 2015 Population                  51368.0
# 2010 Population                  54849.0
# 2000 Population                  58230.0
# 1990 Population                  47818.0
# 1980 Population                  32886.0
# 1970 Population                  27075.0
# Area (km²)                         199.0
# Density (per km²)               222.4774
# Growth Rate                       0.9831
# World Population Percentage          0.0
# Name: American Samoa, dtype: object

# %%
df[df['Rank'] < 10].sort_values(by=['Continent','Country'],ascending=[False,True])
# Out:
#      Rank CCA3  ... Growth Rate World Population Percentage
# 27      7  BRA  ...      1.0046                        2.70
# 221     3  USA  ...      1.0038                        4.24
# 171     9  RUS  ...      0.9973                        1.81
# 16      8  BGD  ...      1.0108                        2.15
# 41      1  CHN  ...      1.0000                       17.88
# 92      2  IND  ...      1.0068                       17.77
# 93      4  IDN  ...      1.0064                        3.45
# 156     5  PAK  ...      1.0191                        2.96
# 149     6  NGA  ...      1.0241                        2.74
#
# [9 rows x 17 columns]
